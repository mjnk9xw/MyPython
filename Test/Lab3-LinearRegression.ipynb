# %%
# %cd "/content/drive/My Drive/DL01/Slide + Code"
# !ls
# Out:
# /content/drive/My Drive/DL01/Slide + Code
#  1.BasicPython.ipynb		       Introduction2DL.pdf
#  autoencoder_noise_reduction.ipynb     Lab2_opencv.ipynb
#  Autoencoder.pdf		       Lab2_pandas.ipynb
# 'CNN Techniques.pdf'		       Lab3-LinearRegression.ipynb
# 'Convolutional Neural Network.ipynb'   Lab4-LogisticRegression.ipynb
# 'Convolutional Neural Network.pdf'    'Linear regression.pdf'
#  data_linear.csv		      'Logistic regression.pdf'
#  dataset.csv			      'loss test.ipynb'
#  data_square.csv		      'Mathematic review.pdf'
#  DCGAN.ipynb			       MNIST-NeuralNetwork.ipynb
#  feature-extractor.ipynb	      'Neural Network.pdf'
#  fine-tune.ipynb		       NeuralNet.zip
#  flower-17.zip			      'Object detection.pdf'
#  GAN.pdf			       RegularSeasonCompactResults.csv
#  images				       RNN.pdf

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data_linear.csv').values
N = data.shape[0]
x = data[:, 0].reshape(-1, 1)
y = data[:, 1].reshape(-1, 1)
plt.scatter(x, y)
plt.xlabel('mét vuông')
plt.ylabel('giá')
# Out:
# Text(0, 0.5, 'giá')

# %%
x = np.hstack((np.ones((N, 1)), x))

w = np.array([0.,1.]).reshape(-1,1)

# %%
numOfIteration = 100
cost = np.zeros((numOfIteration,1))
learning_rate = 0.000001
for i in range(1, numOfIteration):
    r = np.dot(x, w) - y
    cost[i] = 0.5*np.sum(r*r)
    w[0] -= learning_rate*np.sum(r)
    # correct the shape dimension
    w[1] -= learning_rate*np.sum(np.multiply(r, x[:,1].reshape(-1,1)))
    print(cost[i])
# Out:
# [13929872.64455245]
# [10306582.37422079]
# [7625999.18237673]
# [5642849.69326854]
# [4175675.71851866]
# [3090230.83195734]
# [2287196.82094014]
# [1693096.06938209]
# [1253568.35550934]
# [928396.89128833]
# [687828.48611463]
# [509851.12972016]
# [378179.89312088]
# [280766.8575313]
# [208698.72973386]
# [155381.27570385]
# [115935.94816237]
# [86753.4994753]
# [65163.7354763]
# [49191.19268689]
# [37374.38339803]
# [28632.06953731]
# [22164.32937972]
# [17379.36470576]
# [13839.35126131]
# [11220.37783611]
# [9282.80838638]
# [7849.35533562]
# [6788.85776037]
# [6004.28016513]
# [5423.83373397]
# [4994.40765352]
# [4676.70947326]
# [4441.66984614]
# [4267.78268312]
# [4139.13734594]
# [4043.96282366]
# [3973.55068504]
# [3921.4582571]
# [3882.91912046]
# [3854.40698198]
# [3833.3130189]
# [3817.70717153]
# [3806.16154282]
# [3797.61974572]
# [3791.30024382]
# [3786.62484071]
# [3783.16577503]
# [3780.60658031]
# [3778.71312826]
# [3777.31220606]
# [3776.27566738]
# [3775.50870698]
# [3774.94118601]
# [3774.52121437]
# [3774.21040269]
# [3773.98034975]
# [3773.81004376]
# [3773.68393976]
# [3773.59053729]
# [3773.52132808]
# [3773.47001751]
# [3773.43194874]
# [3773.4036765]
# [3773.38265195]
# [3773.36698937]
# [3773.3552937]
# [3773.34653282]
# [3773.33994316]
# [3773.33495981]
# [3773.33116485]
# [3773.32824908]
# [3773.32598375]
# [3773.32419963]
# [3773.32277153]
# [3773.32160681]
# [3773.32063694]
# [3773.31981124]
# [3773.31909219]
# [3773.31845205]
# [3773.31787028]
# [3773.3173317]
# [3773.31682507]
# [3773.31634209]
# [3773.31587659]
# [3773.31542403]
# [3773.31498104]
# [3773.31454514]
# [3773.31411448]
# [3773.3136877]
# [3773.31326379]
# [3773.312842]
# [3773.31242178]
# [3773.31200273]
# [3773.31158454]
# [3773.31116698]
# [3773.3107499]
# [3773.31033317]
# [3773.3099167]

# %%
predict = np.dot(x, w)
plt.plot((x[0][1], x[N-1][1]),(predict[0], predict[N-1]), 'r')
x = data[:, 0].reshape(-1, 1)
y = data[:, 1].reshape(-1, 1)
plt.scatter(x, y)
plt.xlabel('mét vuông')
plt.ylabel('giá')
plt.show()

# %%
x1 = 50
y1 = w[0] + w[1] * 50
print('Giá nhà cho 50m^2 là : ', y1)
# Out:
# Giá nhà cho 50m^2 là :  [755.68795083]

# %%
data = pd.read_csv('data_square.csv').values
N = data.shape[0]
x = data[:, 0].reshape(-1, 1)
y = data[:, 1].reshape(-1, 1)
plt.scatter(x, y)
plt.xlabel('mét vuông')
plt.ylabel('giá')
# Out:
# Text(0, 0.5, 'giá')

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(x, y)

# %%
predict = reg.predict(x)
plt.plot((x[0][0], x[N-1][0]),(predict[0], predict[N-1]), 'r')
x = data[:, 0].reshape(-1, 1)
y = data[:, 1].reshape(-1, 1)
plt.scatter(x, y)
plt.xlabel('mét vuông')
plt.ylabel('giá')
plt.show()

# %%
x = data[:, 0].reshape(-1, 1)
y = data[:, 1].reshape(-1, 1)
x = np.stack([x, np.square(x)], axis=-1)
x = x.reshape(x.shape[0], x.shape[-1])
print(x.shape)
x
# Out:
# (30, 2)
# array([[   30.        ,   900.        ],
#        [   32.4138    ,  1050.65443044],
#        [   34.8276    ,  1212.96172176],
#        [   37.2414    ,  1386.92187396],
#        [   39.6552    ,  1572.53488704],
#        [   42.069     ,  1769.800761  ],
#        [   44.4828    ,  1978.71949584],
#        [   46.8966    ,  2199.29109156],
#        [   49.3103    ,  2431.50568609],
#        [   51.7241    ,  2675.38252081],
#        [   54.1379    ,  2930.91221641],
#        [   56.5517    ,  3198.09477289],
#        [   58.9655    ,  3476.93019025],
#        [   61.3793    ,  3767.41846849],
#        [   63.7931    ,  4069.55960761],
#        [   66.2069    ,  4383.35360761],
#        [   68.6207    ,  4708.80046849],
#        [   71.0345    ,  5045.90019025],
#        [   73.4483    ,  5394.65277289],
#        [   75.8621    ,  5755.05821641],
#        [   78.2759    ,  6127.11652081],
#        [   80.6897    ,  6510.82768609],
#        [   83.1034    ,  6906.17509156],
#        [   85.5172    ,  7313.19149584],
#        [   87.931     ,  7731.860761  ],
#        [   90.3448    ,  8162.18288704],
#        [   92.7586    ,  8604.15787396],
#        [   95.1724    ,  9057.78572176],
#        [   97.5862    ,  9523.06643044],
#        [  100.        , 10000.        ]])

# %%
reg = LinearRegression().fit(x, y)

# %%
a = []
b = []
for i in range(30,100,1):
    j = reg.coef_[0][0] * i + reg.coef_[0][1] * i * i + reg.intercept_
    a.append(i)
    b.append(j)

plt.scatter(a, b, c='r')

x = data[:, 0].reshape(-1, 1)
y = data[:, 1].reshape(-1, 1)
plt.scatter(x, y, c='b')

plt.xlabel('mét vuông')
plt.ylabel('giá')
plt.show()

# %%
print (reg.coef_)
# Out:
# [[-100.00022214    1.00000199]]

# %%
reg.intercept_
# Out:
# array([2000.00579425])
